# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'Sristi Bose',
#  'ECOSANITATION ',
#  'Screenshot 2024-08-30 151659.png',
#  'Aadhaar Card.pdf',
#  'signature.jpg',
#  'Europe',
#  'Project Ecosanitation ',
#  'ec45a739-236d-4187-b831-652e45e38c56.jpeg',
#  'Udaipur Campaign ',
#  'Certificate_of_Completion.pdf',
#  'Saved from Chrome (1)',
#  'Social Media and Graphics Intern (File responses)',
#  'IMG_1154.jpeg',
#  'IMG_1176.jpeg',
#  'IMG_1182.jpeg',
#  'IMG_1197.jpeg',
#  '2530e844-346d-4d54-9375-971e835f2565 (1).jpeg',
#  '2530e844-346d-4d54-9375-971e835f2565.jpeg',
#  'Jamshedpur ',
#  'IMG_1301.jpeg',
#  'e067877b-1fef-47fd-b474-6502c87b85ec.jpeg',
#  'Design Portfolio ',
#  '34d479bc-c5de-495b-978d-2f3eadd5c57b.jpg',
#  '34d479bc-c5de-495b-978d-2f3eadd5c57b (1).jpeg',
#  '34d479bc-c5de-495b-978d-2f3eadd5c57b.jpeg',
#  'Arithmetic circuits.pdf',
#  'Network_Technician_Career_Path_certificate_bose-sristi2005-gmail-com_03720832-884c-48b3-b63b-fa74a2f16dcc.pdf',
#  'Resume_SristiBose.pdf 2.pdf',
#  'SIH2025-Team_JSON_Delulu (5).pptx.pptx',
#  'SIH2025-Team_JSON_Delulu (4).pptx.pptx',
#  'SIH2025-Team_JSON_Delulu (3).pptx.pptx',
#  'SIH2025-Team_JSON_Delulu (2).pptx.pptx',
#  'SIH2025-Team_JSON_Delulu (1).pptx.pptx',
#  'SIH2025-Team_JSON_Delulu (1).pptx',
#  'SIH2025-Team_JSON_Delulu.pptx.pptx',
#  'SIH2025-Team_JSON_Delulu.pptx',
#  'Blue and purple Mental Health modern user information brochure.png',
#  'IMG_0092.jpeg',
#  'Sristi Bose Resume.pdf',
#  'IMG_0093 (1).jpeg',
#  'IMG_0093.jpeg',
#  'Campaign pictures',
#  'Diana Award.gdoc',
#  'Sth.gdoc',
#  'Subject: Request for Permission to Conduct Campaign Shoot and Feature Students.gdoc',
#  'Purple and White Modern Professional Business Presentation.pdf.pdf',
#  'DA IA4.gdoc',
#  'Untitled document (2).gdoc',
#  'DA ASSIGNMENT IA4  (1).docx',
#  'DA ASSIGNMENT IA4 .gdoc',
#  'DA ASSIGNMENT IA4 .docx',
#  'Copy of CAYA Module 1 - Our Advocacy Stories Script  (2).docx',
#  'Copy of CAYA Module 1 - Our Advocacy Stories Script  (1).docx',
#  'Copy of CAYA Module 1 - Our Advocacy Stories Script .docx',
#  'IMG_0153.mov',
#  'TEDx talk idea',
#  'Social Impact Tour(Sristi Bose)',
#  'passport .pdf',
#  'ID card 23 Nov 2025.pdf',
#  'Untitled document (1).gdoc',
#  'IMG_4143.jpeg',
#  'resume (1).pdf',
#  'Global Summit',
#  'Pictures',
#  'resume (1) (1).pdf.pdf',
#  'resume (1).pdf.pdf',
#  'IMG_4196.jpeg',
#  'IMG_4199 (1).jpeg',
#  'IMG_4199.jpeg',
#  'IMG_4201.jpeg',
#  'IMG_4210.jpeg',
#  'IMG_4227.jpeg',
#  'IMG_4236 (1).jpeg',
#  'IMG_4236.jpeg',
#  'IMG_4253 (1).jpeg',
#  'IMG_4253.jpeg',
#  'Captions.gdoc',
#  'Sristi_Resume (3).pdf',
#  'Sristi_Resume (2).pdf',
#  'Sristi_Resume (1).pdf',
#  'Sristi_Resume.pdf',
#  'SRISTIBOSE resume (1) (1).pdf.pdf',
#  'SRISTIBOSE resume (1).pdf.pdf',
#  'Adobe Express Workshop.gform',
#  'Soumya’s Story.gdoc',
#  'Adobe Express Workshop (Responses).gsheet',
#  'Movers Workshop',
#  'Saved from Chrome',
#  'List.xlsx',
#  'Photos CAYA',
#  'Resume_Sristi (2).pdf',
#  'Resume_Sristi (1).pdf',
#  'DBS Synopsis (Sristi Bose).gdoc',
#  'Untitled document.gdoc',
#  'view (2)',
#  'view (1)',
#  'view',
#  'Untitled design.png',
#  'LAB DBMS.gdoc',
#  'Resume_Sristi.pdf',
#  'Untitled folder',
#  'Adobe Scan 22 Mar 2026 (1).pdf',
#  'Copy of 2026 2027 Catalyst Application: Working Doc .gdoc',
#  'conference-template-letter.docx',
#  'Causal Analysis of Immune Biomarkers in Lupus Using Machine Learning.gdoc',
#  'GSE65391_series_matrix.txt.gz']

# %%
import pandas as pd

df = pd.read_csv(
    '/content/drive/MyDrive/GSE65391_series_matrix.txt.gz',
    sep='\t',
    comment='!',
    low_memory=False
)

print(df.shape)
print(df.columns)
print(df.head())
# Out:
# (43799, 997)
# Index(['ID_REF', 'GSM1594219', 'GSM1594220', 'GSM1594221', 'GSM1594222',
#        'GSM1594223', 'GSM1594224', 'GSM1594225', 'GSM1594226', 'GSM1594227',
#        ...
#        'GSM1595213', 'GSM1595214', 'GSM1595215', 'GSM1595216', 'GSM1595217',
#        'GSM1595218', 'GSM1595219', 'GSM1595220', 'GSM1595221', 'GSM1595222'],
#       dtype='object', length=997)
#          ID_REF  GSM1594219  GSM1594220  GSM1594221  GSM1594222  GSM1594223  \
# 0  ILMN_1343291   13.780018   13.612146   14.042542   13.750733   13.469943
# 1  ILMN_1343295   11.081396   10.186098   10.340040   10.241601   10.878306
# 2  ILMN_1651199    3.321928    3.321928    3.321928    3.321928    3.321928
# 3  ILMN_1651209    3.321928    3.321928    3.321928    3.321928    3.321928
# 4  ILMN_1651210    3.645569    3.321928    3.321928    3.321928    3.321928
#
#    GSM1594224  GSM1594225  GSM1594226  GSM1594227  ...  GSM1595213  \
# 0   13.871745   13.732356   13.962190   14.202078  ...   12.770966
# 1   10.990292   10.554911   11.177815   10.507912  ...   10.503821
# 2    3.321928    3.321928    3.321928    3.321928  ...    3.321928
# 3    3.321928    3.321928    3.321928    3.321928  ...    3.321928
# 4    3.321928    3.321928    3.321928    3.321928  ...    3.321928
#
#    GSM1595214  GSM1595215  GSM1595216  GSM1595217  GSM1595218  GSM1595219  \
# 0   13.772815   14.020652   13.678016   13.814081   13.732577   14.078057
# 1   10.370515   11.150643   10.705754   10.923867   10.536564   10.906835
# 2    3.321928    3.321928    3.321928    3.321928    3.321928    3.321928
# 3    3.321928    3.321928    4.456694    3.321928    3.321928    3.321928
# 4    3.321928    3.321928    3.321928    3.321928    3.321928    3.321928
#
#    GSM1595220  GSM1595221  GSM1595222
# 0   13.867857   13.995211   13.515019
# 1   11.521104   11.149346   10.170682
# 2    3.321928    3.321928    3.321928
# 3    3.540932    3.321928    3.321928
# 4    3.321928    3.321928    3.321928
#
# [5 rows x 997 columns]

# %%
df = df.set_index('ID_REF')   # set gene names as index
df = df.T                     # transpose

print(df.shape)
df.head()
# Out:
# (996, 43799)
# ID_REF      ILMN_1343291  ILMN_1343295  ILMN_1651199  ILMN_1651209  \
# GSM1594219     13.780018     11.081396      3.321928      3.321928
# GSM1594220     13.612146     10.186098      3.321928      3.321928
# GSM1594221     14.042542     10.340040      3.321928      3.321928
# GSM1594222     13.750733     10.241601      3.321928      3.321928
# GSM1594223     13.469943     10.878306      3.321928      3.321928
#
# ID_REF      ILMN_1651210  ILMN_1651221  ILMN_1651228  ILMN_1651229  \
# GSM1594219      3.645569      3.328959     11.440348      5.367392
# GSM1594220      3.321928      3.321928     10.984871      5.417670
# GSM1594221      3.321928      3.791721     12.807902      5.022336
# GSM1594222      3.321928      3.321928     14.222797      5.753210
# GSM1594223      3.321928      3.321928     13.368381      5.423558
#
# ID_REF      ILMN_1651230  ILMN_1651232  ...  ILMN_3311145  ILMN_3311150  \
# GSM1594219      3.321928      3.321928  ...      3.321928      3.321928
# GSM1594220      3.321928      3.523189  ...      3.321928      3.321928
# GSM1594221      3.321928      3.321928  ...      3.321928      3.321928
# GSM1594222      3.321928      3.321928  ...      3.321928      3.321928
# GSM1594223      3.321928      3.321928  ...      3.321928      3.321928
#
# ID_REF      ILMN_3311155  ILMN_3311160  ILMN_3311165  ILMN_3311170  \
# GSM1594219      3.321928      3.321928      3.321928      3.321928
# GSM1594220      3.321928      3.321928      3.321928      3.321928
# GSM1594221      3.321928      3.321928      4.259919      3.321928
# GSM1594222      3.321928      3.321928      3.321928      3.321928
# GSM1594223      3.321928      3.321928      3.321928      3.321928
#
# ID_REF      ILMN_3311175  ILMN_3311180  ILMN_3311185  ILMN_3311190
# GSM1594219      3.321928      3.321928      3.321928      4.076274
# GSM1594220      3.321928      3.321928      3.321928      4.076274
# GSM1594221      3.321928      3.321928      3.321928      4.076274
# GSM1594222      3.321928      3.321928      3.321928      4.076274
# GSM1594223      3.321928      3.321928      3.321928      4.076274
#
# [5 rows x 43799 columns]

# %%
import numpy as np

# approx split (based on dataset info)
labels = np.array([1]*924 + [0]*72)  # 1 = SLE, 0 = healthy

df['label'] = labels

# %%
df = df.dropna()

# %%
from sklearn.feature_selection import SelectKBest, f_classif

X = df.drop('label', axis=1)
y = df['label']

selector = SelectKBest(f_classif, k=200)
X_selected = selector.fit_transform(X, y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(
    X_selected, y, test_size=0.2, random_state=42
)

model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.94
